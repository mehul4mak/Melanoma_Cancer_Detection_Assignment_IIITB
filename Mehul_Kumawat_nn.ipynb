# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.7.0-cp38-cp38-win_amd64.whl (430.8 MB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\mak\anaconda3\envs\ml\lib\site-packages (from tensorflow) (3.10.0.0)
# Collecting tensorflow-io-gcs-filesystem>=0.21.0
#   Downloading tensorflow_io_gcs_filesystem-0.22.0-cp38-cp38-win_amd64.whl (1.5 MB)
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.13.3-cp38-cp38-win_amd64.whl (34 kB)
# Collecting keras<2.8,>=2.7.0rc0
#   Downloading keras-2.7.0-py2.py3-none-any.whl (1.3 MB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.42.0-cp38-cp38-win_amd64.whl (3.3 MB)
# Collecting gast<0.5.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in c:\users\mak\anaconda3\envs\ml\lib\site-packages (from tensorflow) (0.36.2)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting flatbuffers<3.0,>=1.12
#   Downloading flatbuffers-2.0-py2.py3-none-any.whl (26 kB)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.19.1-cp38-cp38-win_amd64.whl (895 kB)
# Collecting tensorflow-estimator<2.8,~=2.7.0rc0
#   Downloading tensorflow_estimator-2.7.0-py2.py3-none-any.whl (463 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-1.1.0-py3-none-any.whl
# Requirement already satisfied: six>=1.12.0 in c:\users\mak\anaconda3\envs\ml\lib\site-packages (from tensorflow) (1.15.0)
# Collecting tensorboard~=2.6
#   Downloading tensorboard-2.7.0-py3-none-any.whl (5.8 MB)
# Collecting h5py>=2.9.0
#   Downloading h5py-3.6.0-cp38-cp38-win_amd64.whl (2.8 MB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting libclang>=9.0.1
#   Downloading libclang-12.0.0-py2.py3-none-win_amd64.whl (13.1 MB)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting keras-preprocessing>=1.1.1
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\mak\anaconda3\envs\ml\lib\site-packages (from tensorflow) (1.20.3)
# Collecting absl-py>=0.4.0
#   Downloading absl_py-1.0.0-py3-none-any.whl (126 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\mak\anaconda3\envs\ml\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.25.1)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.3.3-py2.py3-none-any.whl (155 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.6-py3-none-any.whl (97 kB)
# Collecting werkzeug>=0.11.15
#   Downloading Werkzeug-2.0.2-py3-none-any.whl (288 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\mak\anaconda3\envs\ml\lib\site-packages (from tensorboard~=2.6->tensorflow) (52.0.0.post20210125)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Downloading importlib_metadata-4.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\mak\anaconda3\envs\ml\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow) (3.4.1)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mak\anaconda3\envs\ml\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\mak\anaconda3\envs\ml\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\mak\anaconda3\envs\ml\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mak\anaconda3\envs\ml\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2020.12.5)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Installing collected packages: pyasn1, rsa, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, importlib-metadata, google-auth, werkzeug, tensorboard-plugin-wit, tensorboard-data-server, protobuf, markdown, grpcio, google-auth-oauthlib, absl-py, wrapt, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, opt-einsum, libclang, keras-preprocessing, keras, h5py, google-pasta, gast, flatbuffers, astunparse, tensorflow
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 3.10.0
#     Uninstalling importlib-metadata-3.10.0:
#       Successfully uninstalled importlib-metadata-3.10.0
# Successfully installed absl-py-1.0.0 astunparse-1.6.3 cachetools-4.2.4 flatbuffers-2.0 gast-0.4.0 google-auth-2.3.3 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.42.0 h5py-3.6.0 importlib-metadata-4.8.2 keras-2.7.0 keras-preprocessing-1.1.2 libclang-12.0.0 markdown-3.3.6 oauthlib-3.1.1 opt-einsum-3.3.0 protobuf-3.19.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.0 rsa-4.8 tensorboard-2.7.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.7.0 tensorflow-estimator-2.7.0 tensorflow-io-gcs-filesystem-0.22.0 termcolor-1.1.0 werkzeug-2.0.2 wrapt-1.13.3

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization, Rescaling, InputLayer
# from keras.callbacks import EarlyStopping #, ReduceLROnPlateau

# %%
def plot_metrics(history, epochs=20):
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs_range = range(epochs)

  plt.figure(figsize=(12, 4))
  plt.subplot(1, 2, 1)
  plt.plot(epochs_range, acc, label='Training Accuracy')
  plt.plot(epochs_range, val_acc, label='Validation Accuracy')
  plt.legend(loc='lower right')
  plt.title('Training and Validation Accuracy')

  plt.subplot(1, 2, 2)
  plt.plot(epochs_range, loss, label='Training Loss')
  plt.plot(epochs_range, val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Training and Validation Loss')
  plt.show()

#To Remove Augemented Images from Dataset, we will create following method/function

import shutil

def remove_output_files():
  class_names = ['pigmented benign keratosis', 
                'melanoma', 
                'basal cell carcinoma', 
                'nevus', 
                'squamous cell carcinoma', 
                'vascular lesion', 
                'actinic keratosis', 
                'dermatofibroma', 
                'seborrheic keratosis']
  data_dir_train = pathlib.Path("/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
  for i in class_names:
    dir_path = str(data_dir_train) + '/' + str(i)+'/output'
    try:
        shutil.rmtree(dir_path)
    except OSError as e:
        print("Error: %s : %s" % (dir_path, e.strerror))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# # Defining the path for train and test images
# ## Todo: Update the paths of the train and test dataset
# data_dir_train = pathlib.Path("/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
# data_dir_test = pathlib.Path('/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("CNN_assignment\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train")
data_dir_test = pathlib.Path('CNN_assignment\Skin cancer ISIC The International Skin Imaging Collaboration\Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %%
2239+118
# Out:
# 2357

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
tf.keras.utils.image_dataset_from_directory(data_dir_train,validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.
# <BatchDataset shapes: ((None, 180, 180, 3), (None,)), types: (tf.float32, tf.int32)>

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir_train,
  label_mode="int",
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir_train,
  validation_split=0.2,
  label_mode="int",
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %%
for i in class_names:
  print(i,": ",len(list(data_dir_train.glob('{}/*.jpg'.format(i)))))
# Out:
# actinic keratosis :  114
# basal cell carcinoma :  376
# dermatofibroma :  95
# melanoma :  438
# nevus :  357
# pigmented benign keratosis :  462
# seborrheic keratosis :  77
# squamous cell carcinoma :  181
# vascular lesion :  139

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

# %%
image,label=next(train_ds.as_numpy_iterator())
plt.imshow(image)
plt.title(label)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-119-0aae77dae6d0> in <module>
# ----> 1 image,label=next(train_ds.as_numpy_iterator()[:1])
#       2 plt.imshow(image)
#       3 plt.title(label)
#
# TypeError: '_NumpyIterator' object is not subscriptable

# %%
for i,j in train_ds.as_numpy_iterator():
    for i

# %%
plt.figure(figsize=(10,10))
for index,images in enumerate(class_names):
  
  temp=plt.imread(list(data_dir_train.glob('{}/*.jpg'.format(images)))[0])
  
  plt.subplot(3,3,index+1)
  plt.imshow(temp)
  plt.axis('off')
  plt.title(images)

# %%
images, labels= next(iter(train_ds))
print(images.shape)
print(labels.shape)
# Out:
# (32, 180, 180, 3)
# (32,)

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
IMG_SIZE = 180

resize_and_rescale = tf.keras.Sequential([
  layers.Resizing(IMG_SIZE, IMG_SIZE),
  layers.Rescaling(1./255),
    layers.RandomFlip("horizontal"),
    
    layers.RandomZoom(0.5),
    layers.RandomCrop(180,180)
  #layers.RandomRotation(90)
])

# %%
temp=resize_and_rescale(images)

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
 layers.RandomZoom(height_factor=(-.5,0))
])

# %%
plt.imshow(images[1].numpy().astype('uint8'))

# %%
# data_augmentation(images[0])

# %%
plt.figure(figsize=(10, 10))
for i in range(9):
  augmented_image = data_augmentation(images[1])
  ax = plt.subplot(3, 3, i + 1)
  plt.imshow(augmented_image.numpy().astype('uint8'))
#   plt.axis("off")

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Creating and testing how Keras Rescaling layer works

normalization_layer = tf.keras.layers.Rescaling(1./255)


normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.1901961 0.90196085

# %% [markdown]
# ## Model 1 - Vanilla Model

# %%
model=Sequential()
model.add(InputLayer((180,180,3)))
model.add(Rescaling(1./255))

model.add(Conv2D(32, 3, activation='relu',padding='same'))
model.add(MaxPooling2D())

model.add(Conv2D(64, 3, activation='relu',padding='same'))
model.add(MaxPooling2D())

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))

model.add(Dense(9, activation='softmax'))

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### As Adam is the most popular Optmizers and works well on most of the NN Problems. 
### Also, We are having Muti-class classification problem we will choose Loss as SparseCategoricalCrossentropy.
model.compile(optimizer='adam',
              loss=tf.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 129600)            0
#
#  dense (Dense)               (None, 512)               66355712
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 9)                 2313
#
# =================================================================
# Total params: 66,508,745
# Trainable params: 66,508,745
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 57s 846ms/step - loss: 3.5106 - accuracy: 0.2561 - val_loss: 1.6712 - val_accuracy: 0.3915
# Epoch 2/20
# 56/56 [==============================] - 5s 90ms/step - loss: 1.6413 - accuracy: 0.4085 - val_loss: 1.4779 - val_accuracy: 0.5101
# Epoch 3/20
# 56/56 [==============================] - 5s 89ms/step - loss: 1.4488 - accuracy: 0.4855 - val_loss: 1.7792 - val_accuracy: 0.4072
# Epoch 4/20
# 56/56 [==============================] - 5s 89ms/step - loss: 1.4177 - accuracy: 0.5100 - val_loss: 1.5265 - val_accuracy: 0.4720
# Epoch 5/20
# 56/56 [==============================] - 5s 89ms/step - loss: 1.2486 - accuracy: 0.5586 - val_loss: 1.4907 - val_accuracy: 0.5078
# Epoch 6/20
# 56/56 [==============================] - 5s 88ms/step - loss: 1.1431 - accuracy: 0.5898 - val_loss: 1.4374 - val_accuracy: 0.5302
# Epoch 7/20
# 56/56 [==============================] - 5s 89ms/step - loss: 1.0596 - accuracy: 0.6289 - val_loss: 1.6280 - val_accuracy: 0.5078
# Epoch 8/20
# 56/56 [==============================] - 5s 90ms/step - loss: 0.9156 - accuracy: 0.6652 - val_loss: 1.4628 - val_accuracy: 0.4944
# Epoch 9/20
# 56/56 [==============================] - 5s 89ms/step - loss: 0.8345 - accuracy: 0.7076 - val_loss: 2.2160 - val_accuracy: 0.4631
# Epoch 10/20
# 56/56 [==============================] - 5s 90ms/step - loss: 0.6745 - accuracy: 0.7556 - val_loss: 1.8997 - val_accuracy: 0.4787
# Epoch 11/20
# 56/56 [==============================] - 5s 89ms/step - loss: 0.5591 - accuracy: 0.7941 - val_loss: 1.9009 - val_accuracy: 0.5324
# Epoch 12/20
# 56/56 [==============================] - 5s 89ms/step - loss: 0.4455 - accuracy: 0.8304 - val_loss: 2.0529 - val_accuracy: 0.4899
# Epoch 13/20
# 56/56 [==============================] - 5s 89ms/step - loss: 0.3700 - accuracy: 0.8633 - val_loss: 2.3990 - val_accuracy: 0.5190
# Epoch 14/20
# 56/56 [==============================] - 5s 89ms/step - loss: 0.3380 - accuracy: 0.8677 - val_loss: 2.0593 - val_accuracy: 0.5101
# Epoch 15/20
# 56/56 [==============================] - 5s 88ms/step - loss: 0.3195 - accuracy: 0.8800 - val_loss: 2.4827 - val_accuracy: 0.4720
# Epoch 16/20
# 56/56 [==============================] - 5s 88ms/step - loss: 0.3368 - accuracy: 0.8689 - val_loss: 2.5915 - val_accuracy: 0.4698
# Epoch 17/20
# 56/56 [==============================] - 5s 88ms/step - loss: 0.3166 - accuracy: 0.8666 - val_loss: 2.4525 - val_accuracy: 0.5011
# Epoch 18/20
# 56/56 [==============================] - 5s 89ms/step - loss: 0.2082 - accuracy: 0.9180 - val_loss: 2.6312 - val_accuracy: 0.5078
# Epoch 19/20
# 56/56 [==============================] - 5s 89ms/step - loss: 0.1676 - accuracy: 0.9235 - val_loss: 2.6993 - val_accuracy: 0.5168
# Epoch 20/20
# 56/56 [==============================] - 5s 89ms/step - loss: 0.1495 - accuracy: 0.9241 - val_loss: 2.8617 - val_accuracy: 0.5145

# %% [markdown]
# ### Visualizing training results

# %%
plot_metrics(history)

# %% [markdown]
# #### We observe that Model 1 overfits the data exteremly. We need to resolve the issue  of overfitting with several techniques. I.e Dropout, Data Augmentation, and Batch Normalization,

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
# We will use ImageDataGenerator to try for Data Augmentation
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
image_aug=ImageDataGenerator(rescale=1./255,
                   horizontal_flip=True,
                   zoom_range=0.2)

# %%
image_batch,label_batch=next(iter(train_ds))
temp=image_batch[0].numpy()
plt.imshow(temp.astype('uint8'))

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
plt.imshow(image_aug.apply_transform(temp,transform_parameters={'flip_horizontal':True}).astype('uint8'))

# %% [markdown]
# ### Model 2 with Dropout layers
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

model_dp=Sequential()

model_dp.add(InputLayer((180,180,3)))
model_dp.add(Rescaling(1./255))

model_dp.add(Conv2D(32, 3, activation='relu',padding='same'))
model_dp.add(MaxPooling2D())

model_dp.add(Conv2D(64, 3, activation='relu',padding='same'))
model_dp.add(MaxPooling2D())
model_dp.add(Dropout(0.20))

model_dp.add(Flatten())
model_dp.add(Dense(256, activation='relu'))
model_dp.add(Dropout(0.20))

model_dp.add(Dense(9, activation='softmax'))


# View the summary of all layers
model_dp.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_3 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_2 (Conv2D)           (None, 180, 180, 32)      896
#
#  max_pooling2d_2 (MaxPooling  (None, 90, 90, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 90, 90, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 45, 45, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 45, 45, 64)        0
#
#  flatten_1 (Flatten)         (None, 129600)            0
#
#  dense_3 (Dense)             (None, 256)               33177856
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 9)                 2313
#
# =================================================================
# Total params: 33,199,561
# Trainable params: 33,199,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compiling the model

# %%
#choose an appropirate optimiser and loss function
model_dp.compile(optimizer='adam',
              loss=tf.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
epochs = 20
history_dp = model_dp.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 5s 77ms/step - loss: 3.0796 - accuracy: 0.2506 - val_loss: 1.8934 - val_accuracy: 0.3177
# Epoch 2/20
# 56/56 [==============================] - 4s 74ms/step - loss: 1.7874 - accuracy: 0.3571 - val_loss: 1.9051 - val_accuracy: 0.3110
# Epoch 3/20
# 56/56 [==============================] - 4s 74ms/step - loss: 1.6371 - accuracy: 0.4286 - val_loss: 1.6197 - val_accuracy: 0.4452
# Epoch 4/20
# 56/56 [==============================] - 4s 75ms/step - loss: 1.5183 - accuracy: 0.4782 - val_loss: 1.4212 - val_accuracy: 0.5347
# Epoch 5/20
# 56/56 [==============================] - 4s 75ms/step - loss: 1.3314 - accuracy: 0.5357 - val_loss: 1.4459 - val_accuracy: 0.4899
# Epoch 6/20
# 56/56 [==============================] - 4s 74ms/step - loss: 1.2128 - accuracy: 0.5670 - val_loss: 1.4745 - val_accuracy: 0.5168
# Epoch 7/20
# 56/56 [==============================] - 4s 75ms/step - loss: 1.1646 - accuracy: 0.5926 - val_loss: 1.4169 - val_accuracy: 0.5324
# Epoch 8/20
# 56/56 [==============================] - 4s 75ms/step - loss: 1.0324 - accuracy: 0.6417 - val_loss: 1.5077 - val_accuracy: 0.4922
# Epoch 9/20
# 56/56 [==============================] - 4s 75ms/step - loss: 0.9953 - accuracy: 0.6456 - val_loss: 1.5128 - val_accuracy: 0.5280
# Epoch 10/20
# 56/56 [==============================] - 4s 75ms/step - loss: 0.8991 - accuracy: 0.6886 - val_loss: 1.5167 - val_accuracy: 0.5459
# Epoch 11/20
# 56/56 [==============================] - 4s 75ms/step - loss: 0.7998 - accuracy: 0.7232 - val_loss: 1.5449 - val_accuracy: 0.5436
# Epoch 12/20
# 56/56 [==============================] - 4s 75ms/step - loss: 0.7036 - accuracy: 0.7662 - val_loss: 1.6802 - val_accuracy: 0.5056
# Epoch 13/20
# 56/56 [==============================] - 4s 75ms/step - loss: 0.6850 - accuracy: 0.7556 - val_loss: 1.6613 - val_accuracy: 0.5257
# Epoch 14/20
# 56/56 [==============================] - 4s 75ms/step - loss: 0.5700 - accuracy: 0.8092 - val_loss: 1.7915 - val_accuracy: 0.5257
# Epoch 15/20
# 56/56 [==============================] - 4s 75ms/step - loss: 0.5161 - accuracy: 0.8198 - val_loss: 1.9157 - val_accuracy: 0.5503
# Epoch 16/20
# 56/56 [==============================] - 4s 75ms/step - loss: 0.4661 - accuracy: 0.8348 - val_loss: 1.9270 - val_accuracy: 0.5123
# Epoch 17/20
# 56/56 [==============================] - 4s 75ms/step - loss: 0.4140 - accuracy: 0.8560 - val_loss: 2.1227 - val_accuracy: 0.5190
# Epoch 18/20
# 56/56 [==============================] - 4s 75ms/step - loss: 0.3780 - accuracy: 0.8560 - val_loss: 2.1222 - val_accuracy: 0.5324
# Epoch 19/20
# 56/56 [==============================] - 4s 75ms/step - loss: 0.3648 - accuracy: 0.8722 - val_loss: 2.0834 - val_accuracy: 0.5459
# Epoch 20/20
# 56/56 [==============================] - 4s 75ms/step - loss: 0.3488 - accuracy: 0.8694 - val_loss: 2.0367 - val_accuracy: 0.5414

# %% [markdown]
# ### Visualizing the results

# %%
plot_metrics(history_dp)

# %% [markdown]
# #### Obervation: We have reduced the overfitting problem slighlty. However, There is no significant improvement with Model 2 in comparison to Model 1. We assume the issue to be Lower Amount of Data and Class Imbalance.

# %% [markdown]
# #### Let's start Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
for i in class_names:
  print(i,": ",len(list(data_dir_train.glob('{}/*.jpg'.format(i)))))
# Out:
# actinic keratosis :  114
# basal cell carcinoma :  376
# dermatofibroma :  95
# melanoma :  438
# nevus :  357
# pigmented benign keratosis :  462
# seborrheic keratosis :  77
# squamous cell carcinoma :  181
# vascular lesion :  139

# %% [markdown]
# #### Observations:
# #### - *'seborrheic keratosis'* class has the least number of samples.
# #### - 'pigmented benign keratosis' classes dominate the data in terms proportionate number of samples

# %%
import os
import glob
from glob import glob

path_list = [x for x in glob(os.path.join(data_dir_train, '*', '*.jpg'))]
print(path_list)

lesion_list = list()

#for [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*', '*.jpg'))]
for i in glob(os.path.join(data_dir_train, '*', '*.jpg')):
  base_dir_name = os.path.dirname(i)
  #print(base_dir_name)
  lesion_list.append(os.path.basename(base_dir_name))

print(lesion_list)
# Out:
# ['/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025780.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025803.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025825.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025953.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025992.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025957.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026040.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026149.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026171.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026194.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026212.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026457.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026468.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026525.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026575.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026625.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026626.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026650.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026702.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026709.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026729.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026765.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026848.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026857.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026905.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026984.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027172.jpg', '/content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/acti ...
# ['actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'actinic keratosis', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma', 'basal cell carcinoma ...

# %%
import pandas as pd

dataframe_dict = dict(zip(path_list, lesion_list))

original_df = pd.DataFrame(list(dataframe_dict.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/drive/MyDrive/CNN_assignment/Skin can...  actinic keratosis
# 1     /content/drive/MyDrive/CNN_assignment/Skin can...  actinic keratosis
# 2     /content/drive/MyDrive/CNN_assignment/Skin can...  actinic keratosis
# 3     /content/drive/MyDrive/CNN_assignment/Skin can...  actinic keratosis
# 4     /content/drive/MyDrive/CNN_assignment/Skin can...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/drive/MyDrive/CNN_assignment/Skin can...    vascular lesion
# 2235  /content/drive/MyDrive/CNN_assignment/Skin can...    vascular lesion
# 2236  /content/drive/MyDrive/CNN_assignment/Skin can...    vascular lesion
# 2237  /content/drive/MyDrive/CNN_assignment/Skin can...    vascular lesion
# 2238  /content/drive/MyDrive/CNN_assignment/Skin can...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
original_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    462
# melanoma                      438
# basal cell carcinoma          376
# nevus                         357
# squamous cell carcinoma       181
# vascular lesion               139
# actinic keratosis             114
# dermatofibroma                 95
# seborrheic keratosis           77
# Name: Label, dtype: int64

# %% [markdown]
# #### Rectify the class imbalance
# #### We'll use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.9-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.19.5)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.62.3)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.9

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
import Augmentor
balance_file_count = 1000
for i in class_names:
  augmnt_pipeline = Augmentor.Pipeline(str(data_dir_train) + '/'+ i)
  augmnt_pipeline.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
  current_count = len(list(data_dir_train.glob('{}/*.jpg'.format(i))))
  augmnt_pipeline.sample(balance_file_count - current_count)
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FF3A9B4FB90>: 100%|██████████| 886/886 [00:43<00:00, 20.32 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FF3A9B45950>: 100%|██████████| 624/624 [00:30<00:00, 20.17 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FF4C02976D0>: 100%|██████████| 905/905 [00:44<00:00, 20.54 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FF3A988DF10>: 100%|██████████| 562/562 [01:52<00:00,  5.01 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=3072x2304 at 0x7FF3A978B890>: 100%|██████████| 643/643 [02:12<00:00,  4.85 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FF3A98BECD0>: 100%|██████████| 538/538 [00:27<00:00, 19.53 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FF3A9BBAFD0>: 100%|██████████| 923/923 [01:40<00:00,  9.16 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FF4237765D0>: 100%|██████████| 819/819 [00:40<00:00, 20.35 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/drive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FF420045E90>: 100%|██████████| 861/861 [00:43<00:00, 19.98 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 6761

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df2)

# %%
new_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    1000
# squamous cell carcinoma       1000
# seborrheic keratosis          1000
# melanoma                      1000
# actinic keratosis             1000
# nevus                         1000
# basal cell carcinoma          1000
# dermatofibroma                1000
# vascular lesion               1000
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
augmented_data_dir = data_dir_train
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  augmented_data_dir,
  seed=123,
  validation_split = 0.2,
  subset ='training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 9000 files belonging to 9 classes.
# Using 7200 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  augmented_data_dir,
  seed=123,
  validation_split = 0.2,
  subset ='validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 9000 files belonging to 9 classes.
# Using 1800 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
from tensorflow.keras.regularizers import l2

# %%
model_norm=Sequential()

model_norm.add(InputLayer((180,180,3)))
model_norm.add(Rescaling(1./255))

model_norm.add(Conv2D(32, (3, 3), padding='same'))
model_norm.add(BatchNormalization())
model_norm.add(Activation('relu'))

model_norm.add(MaxPooling2D(pool_size=(2, 2)))

model_norm.add(Conv2D(64, (3, 3)))
model_norm.add(BatchNormalization())
model_norm.add(Activation('relu'))


model_norm.add(MaxPooling2D(pool_size=(2, 2)))
model_norm.add(Dropout(0.25))

model_norm.add(Flatten())
model_norm.add(Dense(512, activation='relu',kernel_regularizer=l2(0.01)))
model_norm.add(Dense(256, activation='relu',kernel_regularizer=l2(0.01)))
model_norm.add(Dropout(0.25))

model_norm.add(Dense(9, activation='softmax'))


# View the summary of all layers
model_norm.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_12 (Rescaling)    (None, 180, 180, 3)       0
#
#  conv2d_19 (Conv2D)          (None, 180, 180, 32)      896
#
#  batch_normalization_15 (Bat  (None, 180, 180, 32)     128
#  chNormalization)
#
#  activation_15 (Activation)  (None, 180, 180, 32)      0
#
#  max_pooling2d_14 (MaxPoolin  (None, 90, 90, 32)       0
#  g2D)
#
#  conv2d_20 (Conv2D)          (None, 88, 88, 64)        18496
#
#  batch_normalization_16 (Bat  (None, 88, 88, 64)       256
#  chNormalization)
#
#  activation_16 (Activation)  (None, 88, 88, 64)        0
#
#  max_pooling2d_15 (MaxPoolin  (None, 44, 44, 64)       0
#  g2D)
#
#  dropout_14 (Dropout)        (None, 44, 44, 64)        0
#
#  flatten_10 (Flatten)        (None, 123904)            0
#
#  dense_19 (Dense)            (None, 512)               63439360
#
#  dense_20 (Dense)            (None, 256)               131328
#
#  dropout_15 (Dropout)        (None, 256)               0
#
#  dense_21 (Dense)            (None, 9)                 2313
#
# =================================================================
# Total params: 63,592,777
# Trainable params: 63,592,585
# Non-trainable params: 192
# _________________________________________________________________

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
#choose an appropirate optimiser and loss function
model_norm.compile(optimizer='SGD',
              loss=tf.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 50
## Your code goes here, use 50 epochs.
history_norm = model_norm.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# 225/225 [==============================] - 64s 274ms/step - loss: 14.9797 - accuracy: 0.3668 - val_loss: 14.9220 - val_accuracy: 0.1372
# Epoch 2/50
# 225/225 [==============================] - 64s 281ms/step - loss: 13.1508 - accuracy: 0.5415 - val_loss: 12.9677 - val_accuracy: 0.4189
# Epoch 3/50
# 225/225 [==============================] - 65s 283ms/step - loss: 11.9211 - accuracy: 0.6361 - val_loss: 11.5417 - val_accuracy: 0.5883
# Epoch 4/50
# 225/225 [==============================] - 62s 271ms/step - loss: 10.8278 - accuracy: 0.7129 - val_loss: 10.5196 - val_accuracy: 0.6594
# Epoch 5/50
# 225/225 [==============================] - 68s 299ms/step - loss: 9.8749 - accuracy: 0.7492 - val_loss: 10.1151 - val_accuracy: 0.5372
# Epoch 6/50
# 225/225 [==============================] - 68s 299ms/step - loss: 8.9769 - accuracy: 0.8028 - val_loss: 9.3781 - val_accuracy: 0.5522
# Epoch 7/50
# 225/225 [==============================] - 66s 287ms/step - loss: 8.1986 - accuracy: 0.8301 - val_loss: 7.9985 - val_accuracy: 0.7739
# Epoch 8/50
# 225/225 [==============================] - 66s 287ms/step - loss: 7.4827 - accuracy: 0.8583 - val_loss: 7.4465 - val_accuracy: 0.7511
# Epoch 9/50
# 225/225 [==============================] - 68s 299ms/step - loss: 6.8604 - accuracy: 0.8742 - val_loss: 7.7193 - val_accuracy: 0.5189
# Epoch 10/50
# 225/225 [==============================] - 66s 286ms/step - loss: 6.2863 - accuracy: 0.8875 - val_loss: 6.6001 - val_accuracy: 0.6844
# Epoch 11/50
# 225/225 [==============================] - 65s 285ms/step - loss: 5.7637 - accuracy: 0.8963 - val_loss: 5.7639 - val_accuracy: 0.8267
# Epoch 12/50
# 225/225 [==============================] - 67s 291ms/step - loss: 5.3043 - accuracy: 0.9060 - val_loss: 5.3610 - val_accuracy: 0.8100
# Epoch 13/50
# 225/225 [==============================] - 66s 290ms/step - loss: 4.8373 - accuracy: 0.9192 - val_loss: 5.0667 - val_accuracy: 0.7794
# Epoch 14/50
# 225/225 [==============================] - 67s 291ms/step - loss: 4.4450 - accuracy: 0.9285 - val_loss: 4.5192 - val_accuracy: 0.8461
# Epoch 15/50
# 225/225 [==============================] - 67s 292ms/step - loss: 4.0779 - accuracy: 0.9335 - val_loss: 4.3756 - val_accuracy: 0.7906
# Epoch 16/50
# 225/225 [==============================] - 62s 272ms/step - loss: 3.7434 - accuracy: 0.9390 - val_loss: 4.0284 - val_accuracy: 0.8006
# Epoch 17/50
# 225/225 [==============================] - 66s 288ms/step - loss: 3.4449 - accuracy: 0.9436 - val_loss: 3.5958 - val_accuracy: 0.8428
# Epoch 18/50
# 225/225 [==============================] - 63s 277ms/step - loss: 3.1913 - accuracy: 0.9401 - val_loss: 4.3327 - val_accuracy: 0.6050
# Epoch 19/50
# 225/225 [==============================] - 64s 280ms/step - loss: 2.9182 - accuracy: 0.9490 - val_loss: 3.1220 - val_accuracy: 0.8389
# Epoch 20/50
# 225/225 [==============================] - 64s 279ms/step - loss: 2.7149 - accuracy: 0.9410 - val_loss: 2.9931 - val_accuracy: 0.8239
# Epoch 21/50
# 225/225 [==============================] - 66s 286ms/step - loss: 2.4927 - accuracy: 0.9483 - val_loss: 3.0023 - val_accuracy: 0.7394
# Epoch 22/50
# 225/225 [==============================] - 63s 274ms/step - loss: 2.2927 - accuracy: 0.9518 - val_loss: 3.4248 - val_accuracy: 0.6083
# Epoch 23/50
# 225/225 [==============================] - 66s 287ms/step - loss: 2.2305 - accuracy: 0.9212 - val_loss: 2.5892 - val_accuracy: 0.7933
# Epoch 24/50
# 225/225 [==============================] - 66s 290ms/step - loss: 1.9645 - accuracy: 0.9557 - val_loss: 2.1309 - val_accuracy: 0.8917
# Epoch 25/50
# 225/225 [==============================] - 64s 279ms/step - loss: 1.8101 - accuracy: 0.9582 - val_loss: 2.0492 - val_accuracy: 0.8594
# Epoch 26/50
# 225/225 [==============================] - 64s 281ms/step - loss: 1.6990 - accuracy: 0.9517 - val_loss: 1.9657 - val_accuracy: 0.8400
# Epoch 27/50
# 225/225 [==============================] - 66s 288ms/step - loss: 1.5469 - accuracy: 0.9615 - val_loss: 1.7746 - val_accuracy: 0.8789
# Epoch 28/50
# 225/225 [==============================] - 64s 277ms/step - loss: 1.5133 - accuracy: 0.9406 - val_loss: 3.0684 - val_accuracy: 0.5400
# Epoch 29/50
# 225/225 [==============================] - 63s 276ms/step - loss: 1.3559 - accuracy: 0.9567 - val_loss: 1.6856 - val_accuracy: 0.8472
# Epoch 30/50
# 225/225 [==============================] - 64s 278ms/step - loss: 1.2530 - accuracy: 0.9574 - val_loss: 1.5267 - val_accuracy: 0.8628
# Epoch 31/50
# 225/225 [==============================] - 63s 275ms/step - loss: 1.2039 - accuracy: 0.9476 - val_loss: 1.5760 - val_accuracy: 0.8039
# Epoch 32/50
# 225/225 [==============================] - 62s 271ms/step - loss: 1.1817 - accuracy: 0.9358 - val_loss: 1.6817 - val_accuracy: 0.7583
# Epoch 33/50
# 225/225 [==============================] - 63s 273ms/step - loss: 1.0447 - accuracy: 0.9544 - val_loss: 2.0573 - val_accuracy: 0.6717
# Epoch 34/50
# 225/225 [==============================] - 62s 272ms/step - loss: 0.9608 - accuracy: 0.9606 - val_loss: 1.3104 - val_accuracy: 0.8422
# Epoch 35/50
# 225/225 [==============================] - 60s 263ms/step - loss: 0.9614 - accuracy: 0.9446 - val_loss: 1.5805 - val_accuracy: 0.7706
# Epoch 36/50
# 225/225 [==============================] - 61s 267ms/step - loss: 0.8986 - accuracy: 0.9492 - val_loss: 1.3480 - val_accuracy: 0.7878
# Epoch 37/50
# 225/225 [==============================] - 63s 273ms/step - loss: 0.8273 - accuracy: 0.9567 - val_loss: 1.2900 - val_accuracy: 0.7789
# Epoch 38/50
# 225/225 [==============================] - 60s 261ms/step - loss: 0.8185 - accuracy: 0.9474 - val_loss: 1.0348 - val_accuracy: 0.8661
# Epoch 39/50
# 225/225 [==============================] - 61s 268ms/step - loss: 0.7471 - accuracy: 0.9531 - val_loss: 1.1013 - val_accuracy: 0.8400
# Epoch 40/50
# 225/225 [==============================] - 60s 261ms/step - loss: 0.7113 - accuracy: 0.9529 - val_loss: 0.9569 - val_accuracy: 0.8756
# Epoch 41/50
# 225/225 [==============================] - 62s 272ms/step - loss: 0.6663 - accuracy: 0.9547 - val_loss: 1.0116 - val_accuracy: 0.8467
# Epoch 42/50
# 225/225 [==============================] - 60s 260ms/step - loss: 0.6554 - accuracy: 0.9519 - val_loss: 0.8757 - val_accuracy: 0.8778
# Epoch 43/50
# 225/225 [==============================] - 57s 249ms/step - loss: 0.6017 - accuracy: 0.9583 - val_loss: 1.2081 - val_accuracy: 0.7661
# Epoch 44/50
# 225/225 [==============================] - 59s 259ms/step - loss: 0.5618 - accuracy: 0.9611 - val_loss: 0.8249 - val_accuracy: 0.8828
# Epoch 45/50
# 225/225 [==============================] - 58s 252ms/step - loss: 0.6535 - accuracy: 0.9297 - val_loss: 1.0781 - val_accuracy: 0.7883
# Epoch 46/50
# 225/225 [==============================] - 60s 263ms/step - loss: 0.6070 - accuracy: 0.9417 - val_loss: 0.8460 - val_accuracy: 0.8589
# Epoch 47/50
# 225/225 [==============================] - 62s 269ms/step - loss: 0.5157 - accuracy: 0.9606 - val_loss: 1.0076 - val_accuracy: 0.8089
# Epoch 48/50
# 225/225 [==============================] - 62s 271ms/step - loss: 0.6544 - accuracy: 0.9186 - val_loss: 0.8552 - val_accuracy: 0.8511
# Epoch 49/50
# 225/225 [==============================] - 61s 265ms/step - loss: 0.5063 - accuracy: 0.9551 - val_loss: 0.8206 - val_accuracy: 0.8539
# Epoch 50/50
# 225/225 [==============================] - 61s 268ms/step - loss: 0.4547 - accuracy: 0.9618 - val_loss: 0.8209 - val_accuracy: 0.8467

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
plot_metrics(history_norm,epochs=50)

# %% [markdown]
# # Final Conclusion
#
# ## We observe successive improvement from Model 1 to Model 3:
#
# # Model 1:
# #### Simple CNN Model | Accuracy: 0.9241  | Validation accuracy : 0.5145
#
# # Model 2:
# #### CNN Model with Dropout | Accuracy: 0.8694  | Validation accuracy : 0.5414
#
# # Model 3:
# #### CNN Model with Augmented Data, Dropout and Batch Normalization | Accuracy: 0.9618  | Validation accuracy : 0.8467
#
#
# ## We can improve this accuracy further with proper hyper-parameter. We can use different CNN Configuration, choose loss function, Optimizers and Layers.
